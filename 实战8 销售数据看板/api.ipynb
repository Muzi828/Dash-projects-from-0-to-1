# %%
import pandas as pd
import warnings  #由于版本的关系可能出现警告，忽略掉即可
warnings.filterwarnings('ignore')
data = pd.read_csv('data/train.csv')
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
def get_year_month_day(df,time_col):
    
    '''Extract the year, month, and day of the time field data'''
    
    df[time_col]  = pd.to_datetime(df[time_col])
    df['year'] = df[time_col].dt.year
    df['month'] = df[time_col].dt.month
    df['day'] = df[time_col].dt.day
    return df

# %%
#获取年月日字段
data = get_year_month_day(data,'Order Date')
data.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#获取数据的年份唯一值,核实没有缺失值None
year_ls = data['year'].unique()
year_ls
# Out:
# array([2017, 2016, 2015, 2018], dtype=int64)

# %%
# 获取类别部门唯一值，核实没有缺失值
segment_ls = data['Segment'].unique()
segment_ls
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
#封装获取数据的过程，方便回调
def get_data(year,segment):
    return data[(data['year']==year) & (data['Segment']==segment)]

# %%
#核实数据无误
get_data(2018,'Corporate').head()
# Out:
#     Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 41      42  CA-2018-120999 2018-10-09  15/09/2018  Standard Class    LC-16930
# 43      44  CA-2018-139619 2018-09-19  23/09/2018  Standard Class    ES-14080
# 75      76  US-2018-118038 2018-09-12  11/12/2018     First Class    KB-16600
# 76      77  US-2018-118038 2018-09-12  11/12/2018     First Class    KB-16600
# 77      78  US-2018-118038 2018-09-12  11/12/2018     First Class    KB-16600
#
#      Customer Name    Segment        Country        City  ... Postal Code  \
# 41  Linda Cazamias  Corporate  United States  Naperville  ...     60540.0
# 43      Erin Smith  Corporate  United States   Melbourne  ...     32935.0
# 75     Ken Brennan  Corporate  United States     Houston  ...     77041.0
# 76     Ken Brennan  Corporate  United States     Houston  ...     77041.0
# 77     Ken Brennan  Corporate  United States     Houston  ...     77041.0
#
# ...

# %%
get_data(2018,'Consumer').groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False)[:5]
# Out:
# Sub-Category
# Phones     51264.402
# Chairs     50179.781
# Binders    36527.753
# Copiers    29919.798
# Tables     27675.672
# Name: Sales, dtype: float64

# %%
get_data(2018,'Consumer').groupby('Region')['Sales'].sum().sort_values(ascending=False)[:5]
# Out:
# Region
# West       105850.9985
# East        94525.0390
# Central     67705.9074
# South       60522.5270
# Name: Sales, dtype: float64

# %%
get_data(2018,'Consumer')['Sales'].sum()
# Out:
# 328604.4719

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'year', 'month', 'day'],
#       dtype='object')

# %%
data[['Order Date', 'Customer ID', 'Customer Name','Segment', 'City', 'State', 'Region','Category', 'Sub-Category', 'Product Name','Sales', 'year', 'month']]
# Out:
#      Order Date Customer ID     Customer Name    Segment             City  \
# 0    2017-08-11    CG-12520       Claire Gute   Consumer        Henderson
# 1    2017-08-11    CG-12520       Claire Gute   Consumer        Henderson
# 2    2017-12-06    DV-13045   Darrin Van Huff  Corporate      Los Angeles
# 3    2016-11-10    SO-20335    Sean O'Donnell   Consumer  Fort Lauderdale
# 4    2016-11-10    SO-20335    Sean O'Donnell   Consumer  Fort Lauderdale
# ...         ...         ...               ...        ...              ...
# 9795 2017-05-21    SH-19975     Sally Hughsby  Corporate          Chicago
# 9796 2016-12-01    CS-12490  Cindy Schnelling  Corporate           Toledo
# 9797 2016-12-01    CS-12490  Cindy Schnelling  Corporate           Toledo
# 9798 2016-12-01    CS-12490  Cindy Schnelling  Corporate           Toledo
# 9799 2016-12-01    CS-12490  Cindy Schnelling  Corporate           Toledo
#
#            State   Region         Category Sub-Category  \
# ...

# %%
get_data(2018,'Consumer').groupby(['year', 'month', 'Segment', 'State', 'City'])['Sales'].sum().reset_index()
# Out:
#      year  month   Segment          State           City     Sales
# 0    2018      1  Consumer     California    Los Angeles   845.594
# 1    2018      1  Consumer     California  San Francisco   975.842
# 2    2018      1  Consumer     California       San Jose   413.784
# 3    2018      1  Consumer       Colorado         Denver  1020.263
# 4    2018      1  Consumer    Connecticut      Waterbury     3.520
# ..    ...    ...       ...            ...            ...       ...
# 545  2018     12  Consumer     Washington        Edmonds    88.060
# 546  2018     12  Consumer     Washington           Kent    91.416
# 547  2018     12  Consumer     Washington       Longview    94.360
# 548  2018     12  Consumer     Washington        Seattle  2139.328
# 549  2018     12  Consumer  West Virginia       Wheeling   673.344
#
# [550 rows x 6 columns]
